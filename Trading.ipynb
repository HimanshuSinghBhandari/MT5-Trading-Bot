# %% [markdown]
# pip install MetaTrader5 (Ensure that your Python version is at least 3.11 do not use version 3.12.)

# %%
import MetaTrader5 as mt
from datetime import datetime

# %% [markdown]
# go to ICMARKET and open your deomo accocunt choose MT5 platform , a chart will be open with this

# %%
mt.initialize()
# Out:
# True

# %% [markdown]
# After opening the Demo account a login and signup will be send to your mail , use it and login to the icmarket ( it will make sure that our phython code and trading platdorm are linked )

# %%
login = 523097849 # Use your login info here , Im Changing mine soo it will not work for you
password = 'sA$KO3HT&L' 
server = 'ICMarketsSC-Demo'

# %%
mt.login(login,password,server)
# Out:
# True

# %% [markdown]
#  The code is attempting to retrieve historical price rates for the Tesla Inc. stock on the NASDAQ market with a daily timeframe, starting from the current date and time and going back 100 days

# %%
rates = mt.copy_rates_from('TSLA.NAS',mt.TIMEFRAME_D1,datetime.now(),100)

# %% [markdown]
# The code, when executed, retrieves historical price rates for Tesla Inc. on the NASDAQ market with daily intervals, starting from the current date and time and going back 100 days. The resulting data is stored in the rates variable. If you print or inspect the rates variable, you'll see the historical price data.

# %%
ticker = 'TSLA.NAS'
interval = mt.TIMEFRAME_D1
from_date = datetime.now()
no_of_rows = 100

rates = mt.copy_rates_from(ticker,interval,from_date,no_of_rows)
rates
# Out:
# array([(1694390400, 261.71, 274.83, 260.95, 273.  , 57358, 1, 0),
#        (1694476800, 269.44, 278.35, 266.6 , 267.59, 59218, 1, 0),
#        (1694563200, 271.62, 274.93, 268.12, 271.32, 46456, 1, 0),
#        (1694649600, 271.1 , 276.69, 270.97, 276.06, 43348, 1, 0),
#        (1694736000, 276.35, 277.15, 271.03, 273.99, 52927, 1, 0),
#        (1694995200, 268.9 , 269.98, 263.76, 265.07, 41865, 1, 0),
#        (1695081600, 267.76, 267.76, 261.18, 266.43, 37903, 1, 0),
#        (1695168000, 265.78, 273.9 , 262.79, 263.71, 50169, 1, 0),
#        (1695254400, 258.09, 260.82, 254.21, 256.7 , 47171, 1, 0),
#        (1695340800, 255.6 , 256.12, 244.47, 244.65, 48708, 1, 0),
#        (1695600000, 238.85, 247.05, 238.3 , 245.99, 42736, 1, 0),
#        (1695686400, 244.83, 249.51, 242.93, 244.11, 41464, 1, 0),
#        (1695772800, 242.71, 245.27, 234.57, 240.44, 56210, 1, 0),
#        (1695859200, 241.67, 247.51, 238.76, 246.16, 49002, 1, 0),
# ...

# %% [markdown]
# By executing this code, you are obtaining information about the trading account linked to the MetaTrader 5 instance. The details in account_info may include account balance, equity, margin, free margin, and other relevant information about the trading account

# %%
account_info = mt.account_info()
account_info

# %%
account_info.balance
# Out:
# 500000.0

# %% [markdown]
# By executing this code, you are obtaining the total count of symbols available for trading in the MetaTrader 5 platform. These symbols can include various financial instruments such as stocks, forex pairs, commodities, and indices

# %%
num_symbols = mt.symbols_total()
num_symbols
# Out:
# 2125

# %%
symbol_info = mt.symbols_get()
symbol_info
# Out:
# (SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1706715482, digits=5, spread=0, spread_float=True, ticks_bookdepth=10, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.08483, bidhigh=1.08574, bidlow=1.08062, ask=1.08483, askhigh=1.08574, asklow=1.08062, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.0, trade_tick_value_profit=1.0, trade_tick_value_loss=1.0, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=200.0, volu
# ...

# %%
mt.symbol_info('TSLA.NAS')
# Out:
# SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1706816865, digits=2, spread=10, spread_float=True, ticks_bookdepth=0, trade_calc_mode=2, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=5, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=187.19, bidhigh=189.76, bidlow=184.21, ask=187.29, askhigh=189.88, asklow=184.35, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.1, volume_max=1000.0, volume_step=0.1
# ...

# %%
import pandas as pd

# %% [markdown]
# If you print or inspect the ohlc DataFrame, you will see a tabular representation of the historical OHLC data for Tesla Inc. on the NASDAQ market at 1-minute intervals within the specified date range.

# %%
ohlc = pd.DataFrame(mt.copy_rates_range('TSLA.NAS',mt.TIMEFRAME_M1, datetime(2024,1,31),datetime.now()))
ohlc
# Out:
#            time    open    high     low   close  tick_volume  spread  \
# 0    1706639400  193.23  193.34  193.12  193.30           40       5
# 1    1706639460  193.35  193.59  193.35  193.59           44       4
# 2    1706639520  193.59  193.60  193.45  193.45           42       3
# 3    1706639580  193.43  193.51  193.28  193.28           37       4
# 4    1706639640  193.28  193.37  193.21  193.21           38       4
# ..          ...     ...     ...     ...     ...          ...     ...
# 710  1706809200  186.17  186.43  186.08  186.15           54       3
# 711  1706809260  186.16  186.30  185.88  185.88           58       5
# 712  1706809320  185.90  185.94  185.77  185.87           62       4
# 713  1706809380  185.88  185.89  185.76  185.87           44       3
# 714  1706809440  185.92  185.92  185.56  185.63           61       3
#
#      real_volume
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# ...

# %%
ohlc['time'] = pd.to_datetime(ohlc['time'], unit='s')
ohlc
# Out:
#                    time    open    high     low   close  tick_volume  spread  \
# 0   2024-01-30 18:30:00  193.23  193.34  193.12  193.30           40       5
# 1   2024-01-30 18:31:00  193.35  193.59  193.35  193.59           44       4
# 2   2024-01-30 18:32:00  193.59  193.60  193.45  193.45           42       3
# 3   2024-01-30 18:33:00  193.43  193.51  193.28  193.28           37       4
# 4   2024-01-30 18:34:00  193.28  193.37  193.21  193.21           38       4
# ..                  ...     ...     ...     ...     ...          ...     ...
# 710 2024-02-01 17:40:00  186.17  186.43  186.08  186.15           54       3
# 711 2024-02-01 17:41:00  186.16  186.30  185.88  185.88           58       5
# 712 2024-02-01 17:42:00  185.90  185.94  185.77  185.87           62       4
# 713 2024-02-01 17:43:00  185.88  185.89  185.76  185.87           44       3
# 714 2024-02-01 17:44:00  185.92  185.92  185.56  185.63           61       3
#
#      real_volume
# 0              0
# ...

# %%
import plotly.express as px
fig = px.line(ohlc, x = ohlc['time'] , y=ohlc['close'])
fig.show()

# %% [markdown]
# https://www.mql5.com/en/docs/python_metatrader5  access this documentation and and go to order_check solution for better understanding.
#
# This code related to placing a trading order for the USDJPY currency pair using the MetaTrader 5 (mt5) Python library

# %%
symbol = "USDJPY"
symbol_info = mt.symbol_info_tick("USDJPY")
price = symbol_info.ask
    
request = {
    "action": mt.TRADE_ACTION_DEAL,
    "symbol": symbol,
    "volume": 0.01,
    "type": mt.ORDER_TYPE_BUY,
    "price": price,
    "sl": 29000.0,
    "tp":  33000.0,
    "comment": "python script buy",
    "type_time": mt.ORDER_TIME_GTC,
    "type_filling": mt.ORDER_FILLING_IOC,
}
 
# perform the check and display the result 'as is'
result = mt.order_send(request)
result
# Out:
# OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=0, order=0, symbol='USDJPY', volume=0.01, price=146.297, stoplimit=0.0, sl=29000.0, tp=33000.0, deviation=0, type=0, type_filling=1, type_time=0, expiration=0, comment='python script buy', position=0, position_by=0))

# %% [markdown]
# This code appears to be placing a trading order for selling (shorting) the USDJPY currency pair using the MetaTrader 5 (mt5) Python library

# %%
 
request = {
    "action": mt.TRADE_ACTION_DEAL,
    "symbol": "USDJPY",
    "volume": 0.01,
    "type": mt.ORDER_TYPE_SELL,
    "price": mt.symbol_info_tick("USDJPY").bid,
    "sl": 31000.0,
    "tp":  33000.0,
    "comment": "python script buy",
    "type_time": mt.ORDER_TIME_GTC,
    "type_filling": mt.ORDER_FILLING_IOC,
}
 
# perform the check and display the result 'as is'
order = mt.order_send(request)
order
# Out:
# OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=0, order=0, symbol='USDJPY', volume=0.01, price=146.295, stoplimit=0.0, sl=31000.0, tp=33000.0, deviation=0, type=1, type_filling=1, type_time=0, expiration=0, comment='python script buy', position=0, position_by=0))

# %% [markdown]
# If you print or inspect the result variable, you will see details about the order execution, including whether it was successful or encountered any errors

# %%
   
request = {
    "action": mt.TRADE_ACTION_DEAL,
    "symbol": symbol,
    "volume": 0.01,
    "type": mt.ORDER_TYPE_SELL,
    "position": 0,
    "price": mt.symbol_info_tick("USDJPY").bid,
    "comment": "python script buy",
    "type_time": mt.ORDER_TIME_GTC,
    "type_filling": mt.ORDER_FILLING_IOC,
}
 
# perform the check and display the result 'as is'
result = mt.order_send(request)
result
# Out:
# OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=0, order=0, symbol='USDJPY', volume=0.01, price=146.296, stoplimit=0.0, sl=0.0, tp=0.0, deviation=0, type=1, type_filling=1, type_time=0, expiration=0, comment='python script buy', position=0, position_by=0))

# %% [markdown]
# # Trading Bot

# %% [markdown]
# "Utilize the knowledge gained above and endeavor to automate each function."

# %%
ticker = 'BTCUSD'
qty = 0.01
buy_order_type = mt.ORDER_TYPE_BUY
sell_order_type = mt.ORDER_TYPE_SELL
buy_price = mt.symbol_info_tick("BTCUSD").ask
sell_price = mt.symbol_info_tick("BTCUSD").bid
sl_pct = 0.05 #stop loss
tp_pct = 0.1  #take profit 
buy_sl = buy_price * (1-sl_pct)
buy_tp = buy_price * (1+tp_pct)
sell_sl = sell_price * (1+sl_pct)
sell_tp = sell_price * (1-tp_pct)

def create_order(ticker , qty , order_type , price , sl, tp):
 request = {
     "action": mt.TRADE_ACTION_DEAL,
     "symbol": ticker ,
     "volume": qty,
     "type":  order_type, 
     "price": price,
     "sl": sl,
     "tp": tp,
     "comment": "python Open Position ",
     "type_time": mt.ORDER_TIME_GTC,
     "type_filling": mt.ORDER_FILLING_IOC,
 }
 order = mt.order_send(request)
 return order

#  def close_order(ticker , qty , order_type , price , position):
#   request = {
#     "action": mt.TRADE_ACTION_DEAL,
#     "symbol": ticker,
#     "volume": qty,
#     "type": order_type,
#     "position":position,   #mt.positions_get()[0]._asdict()['ticket'], #It shouldnt go out of range 
#     "price":  price,
#     "comment": "Close Position",
#     "type_time": mt.ORDER_TIME_GTC,
#     "type_filling": mt.ORDER_FILLING_IOC,
#  }
 
# perform the check and display the result 'as is'
result = mt.order_send(request)

# %%
def close_order(ticker , qty , order_type , price , position):
  request = {
    "action": mt.TRADE_ACTION_DEAL,
    "symbol": ticker,
    "volume": qty,
    "type": order_type,
    "position":position,   #mt.positions_get()[0]._asdict()['ticket'], #It shouldnt go out of range 
    "price":  price,
    "comment": "Close Position",
    "type_time": mt.ORDER_TIME_GTC,
    "type_filling": mt.ORDER_FILLING_IOC,
 }
  
  result = mt.order_send(request)

# %%
create_order(ticker , qty , buy_order_type ,  buy_price , buy_sl, buy_tp)
# Out:
# OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=0, order=0, symbol='BTCUSD', volume=0.01, price=42960.95, stoplimit=0.0, sl=40812.9025, tp=47257.045, deviation=0, type=0, type_filling=1, type_time=0, expiration=0, comment='python Open Position ', position=0, position_by=0))

# %%
close_order(ticker , qty , sell_order_type , sell_price , 0)

# %% [markdown]
# If you run the code below, you will observe in your IC Markets app that your bot is trading automatically based on the current situation.

# %%
import time
for i in range(100):
   ohlc = pd.DataFrame(mt.copy_rates_range('BTCUSD',mt.TIMEFRAME_M1, datetime(2024,2,1),datetime.now()))
   
   ohlc['time'] = pd.to_datetime(ohlc['time'], unit='s')
   print(ohlc)

   current_close=list(ohlc[-1:]['close'])[0]
   last_close = list(ohlc[-2:]['close'])[0]
   last_high = list(ohlc[-2:]['high'])[0]
   last_low = list(ohlc[-2:]['low'])[0]

   long_condition = current_close > last_high
   short_condition = current_close < last_low
   closelong_condition = current_close < last_close
   closeshort_condition = current_close > last_close

   already_buy = False
   already_sell = False

   try:
    already_sell = mt.positions_get()[0]._asdict()['type'] == 1
    already_buy = mt.positions_get()[0]._asdict()['type'] == 0
   except:
    pass


   no_position = len(mt.positions_get())==0

   if long_condition:
      if no_position:
       create_order(ticker , qty , buy_order_type ,  buy_price , buy_sl, buy_tp)
      print("Buy order Placed")
      if already_sell:
         close_order(ticker,qty,buy_order_type,buy_price,0)
         print("Sell Position Closed")
         time.sleep(1)
         create_order(ticker , qty , buy_order_type ,  buy_price , buy_sl, buy_tp)
         print("Buy order Placed")

   if short_condition:
      if no_position:
         create_order(ticker , qty , sell_order_type ,  sell_price , sell_sl, sell_tp)
         print("Sell Order placed")
      if already_buy:
         close_order(ticker,qty,buy_order_type,buy_price,0)
         print("buy Position Closed")
         time.sleep(1)
         create_order(ticker , qty , sell_order_type ,  sell_price , sell_sl, sell_tp)
         print("Buy order Placed")


   try:
    already_sell = mt.positions_get()[0]._asdict()['type'] == 1
    already_buy = mt.positions_get()[0]._asdict()['type'] == 0
   except:
    pass
         
   if closelong_condition and already_buy:
      close_order(ticker,qty,buy_order_type,buy_price,0)
      print("Only Buy Position Closed")
   if closeshort_condition and already_sell:
      close_order(ticker,qty,buy_order_type,buy_price,0)
      print("Only Sell Position Closed")

   already_buy = False
   already_sell = False
   time.sleep(60)
# Out:
#                     time      open      high       low     close  tick_volume  \
# 0    2024-01-31 18:30:00  43444.91  43452.16  43382.56  43393.05          126
# 1    2024-01-31 18:31:00  43393.20  43399.05  43358.81  43362.40           87
# 2    2024-01-31 18:32:00  43362.15  43375.40  43344.72  43358.78          123
# 3    2024-01-31 18:33:00  43360.29  43384.62  43355.72  43355.72          102
# 4    2024-01-31 18:34:00  43359.61  43364.80  43352.01  43357.12           74
# ...                  ...       ...       ...       ...       ...          ...
# 1388 2024-02-01 17:44:00  42687.15  42703.54  42685.40  42694.24          108
# 1389 2024-02-01 17:45:00  42694.24  42698.52  42669.41  42677.01           74
# 1390 2024-02-01 17:46:00  42677.01  42677.01  42635.30  42644.37          140
# 1391 2024-02-01 17:47:00  42648.26  42670.70  42632.84  42665.69          132
# 1392 2024-02-01 17:48:00  42665.69  42687.94  42663.54  42677.40          117
#
#       spread  real_volume
# ...

# %% [markdown]
# # Practice to make my model more refine

# %%
create_order(ticker , qty , buy_order_type , price , buy_sl, buy_tp)
# Out:
# OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=0, order=0, symbol='BTCUSD', volume=0.01, price=146.689, stoplimit=0.0, sl=40073.1755, tp=46400.51900000001, deviation=0, type=0, type_filling=1, type_time=0, expiration=0, comment='python Open Position ', position=0, position_by=0))

# %%
len(mt.positions_get())==0
# Out:
# True

# %%
create_order(ticker , qty , sell_order_type , price , sell_sl, sell_tp)
# Out:
# OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=0, order=0, symbol='BTCUSD', volume=0.01, price=146.689, stoplimit=0.0, sl=44279.035500000005, tp=37953.459, deviation=0, type=1, type_filling=1, type_time=0, expiration=0, comment='python Open Position ', position=0, position_by=0))

# %%
ohlc = pd.DataFrame(mt.copy_rates_range('BTCUSD',mt.TIMEFRAME_M1, datetime(2024,1,31),datetime.now()))
ohlc['time'] = pd.to_datetime(ohlc['time'], unit='s')
ohlc
# Out:
#                     time      open      high       low     close  tick_volume  \
# 0    2024-01-30 18:30:00  43291.49  43319.32  43286.03  43309.63          107
# 1    2024-01-30 18:31:00  43306.87  43339.17  43304.77  43327.02          102
# 2    2024-01-30 18:32:00  43326.73  43360.66  43325.23  43356.16           98
# 3    2024-01-30 18:33:00  43356.99  43359.47  43331.95  43336.49           72
# 4    2024-01-30 18:34:00  43336.52  43352.68  43318.57  43347.05           93
# ...                  ...       ...       ...       ...       ...          ...
# 2789 2024-02-01 17:11:00  42761.27  42771.68  42721.01  42730.24          200
# 2790 2024-02-01 17:12:00  42731.65  42749.36  42699.26  42748.89          187
# 2791 2024-02-01 17:13:00  42748.89  42769.10  42734.02  42756.20           87
# 2792 2024-02-01 17:14:00  42754.50  42794.47  42738.12  42783.39          182
# 2793 2024-02-01 17:15:00  42783.29  42790.75  42744.88  42747.76          185
#
#       spread  real_volume
# ...

# %% [markdown]
# # If you encounter any issues with my code, feel free to visit my GitHub and leave a message there. I'll do my best to assist you
